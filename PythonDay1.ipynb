# %% [markdown]
# <a href="https://colab.research.google.com/github/awanee02/PythonLearningJourney/blob/main/PythonDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World! I am learning Python with Grok!")
# Out:
# Hello World! I am learning Python with Grok!

# %% [markdown]
# Variables

# %%
student_name = "Awanee"
age = 22
city = "Pune"
is_learning_Python = True

print("Student Name: ", student_name)
print("Age: ", age)
print("Lives in: ", city)
print("Student is learning a new language", is_learning_Python)
# Out:
# Student Name:  Awanee
# Age:  22
# Lives in:  Pune
# Student is learning a new language True

# %% [markdown]
# Datatypes in Python

# %%
a = 10                      #int
b = 3.14                    #float
c = 'Learning Python'       #string
d = True                    #boolean

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Basic Math and String Operations

# %%
x = 12
y = 6

print(x + y)      #Addition
print(x - y)      #Subtraction
print(x * y)      #Multiplication
print(x / y)      #Division
print(x // y)     #Floor Division (no decimal)
print(x % y)      #Remainder
print(x ** 2)     #Power 2 in this case

#String operation
greeting = "Hello"
name = "Awanee"
print(greeting + " " + name)
# Out:
# 18
# 6
# 72
# 2.0
# 2
# 0
# 144
# Hello Awanee

# %% [markdown]
# Exercise 1: Create variables for:
#
# Your name
# Your age
# Your favorite food
# Whether you like coding (True/False)

# %%
name = "Awanee"
age = 22
favorite_food = 'Dosa'
like_coding = False

print("Name: ", name)
print("Age: ", age)
print("Person loves to eat: ", favorite_food)
print("Does the person like coding?: ", like_coding)
# Out:
# Name:  Awanee
# Age:  22
# Person loves to eat:  Dosa
# Does the person like coding?:  False

# %% [markdown]
# Exercise 2: Calculate these and print the result:
#
# 25 + 17
#
# 50 - 23
#
# 8 * 6
#
# 100 / 4
#
# 17 % 5   (remainder when 17 divided by 5)

# %%
a = 25
b = 17
c = 50
d = 23
e = 8
f = 6
g = 100
h = 4
i = 5

print(a + b)
print(c- d)
print(e * f)
print(g / h)
print(b % i)
# Out:
# 42
# 27
# 48
# 25.0
# 2

# %% [markdown]
# Exercise 3: Fix the mistakes in this code (there are 4 errors):
# name = Arnav          # missing quotes
#
# age = "25"            # should be number?
#
# print(Name)           # wrong variable name
#
# print("I am " + age + " years old")

# %%
name = "Arnav"
age = 25
print("Name: ", name)
print("I am 25 years old")
# Out:
# Name:  Arnav
# I am 25 years old

# %% [markdown]
# Today's Mini-Project: "About Me" Program
# Write a complete program that prints a nice introduction about yourself.
# Requirements:
#
# Use at least 6 different variables
#
# Use both numbers and text
#
# Use at least one calculation (example: birth year = current year - age)
#
# Make the output look friendly and readable

# %%
name = "Arnav"
age = 25
city = "Pune"
current_year = 2026
birth_year = (current_year - age)
print("Hi! My name is", name)
print("I am " " years old", age)
print("I was born in", birth_year)
print("Today I wrote my first full Python program!")
# Out:
# Hi! My name is Arnav
# I am  years old 25
# I was born in 2001
# Today I wrote my first full Python program!

# %%
name = "Arnav"
age = 25
city = "Pune"
current_year = 2026
birth_year = (current_year - age)
print("Hi! My name is", name)
print("I am", age, "years old")
print("I was born in", birth_year)
print("Today I wrote my first full Python program!")
# Out:
# Hi! My name is Arnav
# I am 25 years old
# I was born in 2001
# Today I wrote my first full Python program!
